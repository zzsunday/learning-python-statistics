# %%
html=""" </dd>
                <dd>
                        <i class="board-index board-index-2">2</i>
    <a href="/films/1297" title="肖申克的救赎" class="image-link" data-act="boarditem-click" data-val="{movieId:1297}">
      <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
      <img data-src="https://p0.meituan.net/movie/283292171619cdfd5b240c8fd093f1eb255670.jpg@160w_220h_1e_1c" alt="肖申克的救赎" class="board-img" />
    </a>
    <div class="board-item-main">
      <div class="board-item-content">
              <div class="movie-item-info">
        <p class="name"><a href="/films/1297" title="肖申克的救赎" data-act="boarditem-click" data-val="{movieId:1297}">肖申克的救赎</a></p>
        <p class="star">
                主演：蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿
        </p>
<p class="releasetime">上映时间：1994-09-10(加拿大)</p>    </div>
    <div class="movie-item-number score-num">
<p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>        
    </div>

      </div>
    </div>

                </dd>
                <dd>"""

# %%
import re
a= re.findall(r'\d{4}-\d{2}-\d{2}.*',html)
print(a)
# Out:
# ['1994-09-10(加拿大)</p>    </div>']

# %%
print(re.findall(r'\d{4}-\d{2}-\d{2}.{3}',html))
# Out:
# ['1994-09-10(加拿']

# %%
print(re.findall(r'\d{4}-\d{2}-\d{2}.{5}',html))
# Out:
# ['1994-09-10(加拿大)']

# %%
print(re.findall(r'<p class="releasetime">[\d\D]+?</p>',html))
# Out:
# ['<p class="releasetime">上映时间：1994-09-10(加拿大)</p>']

# %%
print(re.findall(r'<p class="releasetime">[\d\D]+</p>?',html))
# Out:
# ['<p class="releasetime">上映时间：1994-09-10(加拿大)</p>    </div>\n    <div class="movie-item-number score-num">\n<p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>']

# %%
print(re.findall(r'<p class="releasetime">[.*]+?</p>',html))
# Out:
# []

# %%
print(re.findall(r'<p class="releasetime">.?</p>',html))
# Out:
# []

# %%
print(re.findall(r'<p class="releasetime">.+?</p>',html))
# Out:
# ['<p class="releasetime">上映时间：1994-09-10(加拿大)</p>']

# %%
print(re.findall(r'<p class="releasetime">.*?</p>',html))
# Out:
# ['<p class="releasetime">上映时间：1994-09-10(加拿大)</p>']

# %% [markdown]
# ###  re:匹配括号内的表达式，也表示一个组

# %%
print(re.findall(r'<p class="releasetime">(.*?)</p>',html))
# Out:
# ['上映时间：1994-09-10(加拿大)']
