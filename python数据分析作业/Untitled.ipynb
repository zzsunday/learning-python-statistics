# %% [markdown]
# # Pyhon数据分析

# %%
def a(obj,index):
    return obj[index]
x='spam'
try:
    a(x,4)
except:
    print('error')
# Out:
# error

# %%
def a(obj,index):
    return obj[index]
x='spam'
try:
    a(x,4)
except:
    print('error')
# Out:
# error
